# %%
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import cm
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\train_revised_11.09.2018\train_revised.csv')

# %%
df.head()
# Out:
#    ride_id seat_number payment_method payment_receipt travel_date travel_time  \
# 0     1442         15A          Mpesa      UZUEHCBUSO  10/17/2017        7:15
# 1     5437         14A          Mpesa      TIHLBUSGTE  11/19/2017        7:12
# 2     5710          8B          Mpesa      EQX8Q5G19O  11/26/2017        7:05
# 3     5777         19A          Mpesa      SGP18CL0ME  11/27/2017        7:10
# 4     5778         11A          Mpesa      BM97HFRGL9  11/27/2017        7:12
#
#   travel_from travel_to car_type  max_capacity
# 0      Migori   Nairobi      Bus            49
# 1      Migori   Nairobi      Bus            49
# 2      Keroka   Nairobi      Bus            49
# 3    Homa Bay   Nairobi      Bus            49
# 4      Migori   Nairobi      Bus            49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51645 entries, 0 to 51644
# Data columns (total 10 columns):
# ride_id            51645 non-null int64
# seat_number        51645 non-null object
# payment_method     51645 non-null object
# payment_receipt    51645 non-null object
# travel_date        51645 non-null object
# travel_time        51645 non-null object
# travel_from        51645 non-null object
# travel_to          51645 non-null object
# car_type           51645 non-null object
# max_capacity       51645 non-null int64
# dtypes: int64(2), object(8)
# memory usage: 3.9+ MB

# %%
df.describe()
# Out:
#             ride_id  max_capacity
# count  51645.000000  51645.000000
# mean   10188.645793     34.534321
# std     2211.295708     18.451193
# min     1442.000000     11.000000
# 25%     8287.000000     11.000000
# 50%    10353.000000     49.000000
# 75%    12029.000000     49.000000
# max    20117.000000     49.000000

# %%
corr = df.corr()

# %%
print(corr)
# Out:
#                ride_id  max_capacity
# ride_id       1.000000      0.295902
# max_capacity  0.295902      1.000000

# %%
df.interpolate()
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO  10/17/2017
# 1         5437         14A          Mpesa      TIHLBUSGTE  11/19/2017
# 2         5710          8B          Mpesa      EQX8Q5G19O  11/26/2017
# 3         5777         19A          Mpesa      SGP18CL0ME  11/27/2017
# 4         5778         11A          Mpesa      BM97HFRGL9  11/27/2017
# 5         5777         18B          Mpesa      B6PBDU30IZ  11/27/2017
# 6         5777         14A          Mpesa      MZHGDGS6QZ  11/27/2017
# 7         5778          25          Mpesa      MYVTYFNXDZ  11/27/2017
# 8         5778         21B          Mpesa      TE1WYK1NYE  11/27/2017
# 9         5781         22A          Mpesa      VGG7Q3MVJX  11/27/2017
# 10        5781         18B          Mpesa      YJ7JFHOGKA  11/27/2017
# 11        5781         17B          Mpesa      4JQOSC881A  11/27/2017
# ...

# %%
df['travel_date'].value_counts()
# Out:
# 10/12/2017    856
# 14-12-17      797
# 13-12-17      730
# 07/12/2017    723
# 08/12/2017    722
# 04/03/2018    703
# 17-12-17      689
# 21-12-17      630
# 09/02/2018    616
# 02/03/2018    608
# 06/12/2017    604
# 15-12-17      601
# 11/03/2018    598
# 11/02/2018    597
# 16-02-18      591
# 28-01-18      583
# 04/02/2018    581
# 09/03/2018    558
# 02/02/2018    555
# 18-12-17      555
# 13-02-18      542
# 05/03/2018    540
# 19-12-17      540
# 20-12-17      536
# 29-01-18      528
# 28-02-18      520
# 19-02-18      519
# 07/03/2018    517
# 18-02-18      512
# 05/02/2018    511
#              ...
# 16-01-18      195
# 25-02-18      193
# 03/01/2018    182
# 08/01/2018    176
# 05/04/2018    173
# 30-12-17      172
# 31-03-18      170
# 30-01-18      168
# 25-01-18      168
# 17-03-18      156
# 03/12/2017    152
# 13-01-18      146
# 15-01-18      131
# 20-01-18      129
# 31-12-17      128
# 04/01/2018    123
# 07/01/2018    114
# 06/01/2018    113
# 05/01/2018     88
# ...

# %%
df.sort_values(by='travel_from')
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 51299    20117          1X          Mpesa      BUSNKXBGQS    27-11-17
# 50947    20116           6          Mpesa      EZHIPJIS2T    27-11-17
# 38760    20115           2          Mpesa      UBXFINPUSN  06/12/2017
# 38761    20115          10          Mpesa      LLS9SJZO1E  06/12/2017
# 38758    20115           3          Mpesa      S3VPRF5XX7  06/12/2017
#
#       travel_time travel_from travel_to car_type  max_capacity
# 51299        5:00       Kisii   Nairobi      Bus            49
# 50947        7:10       Kisii   Nairobi  shuttle            11
# 38760        7:10       Kisii   Nairobi  shuttle            11
# 38761        7:10       Kisii   Nairobi  shuttle            11
# 38758        7:10       Kisii   Nairobi  shuttle            11

# %%
df.sort_values(by=['travel_time', 'travel_from'], ascending=[True, False]).head()
# Out:
#       ride_id seat_number payment_method payment_receipt travel_date  \
# 411      6067           1          Mpesa      NCP6X8RHF7    31-03-18
# 1370     6494           8          Mpesa      TTXIXIKZ9H    13-03-18
# 1371     6494          10          Mpesa      AAQY6NXKB4    13-03-18
# 1372     6494           9          Mpesa      TNR7C35DS1    13-03-18
# 2061     6640           1          Mpesa      LMMFPPDH2V  11/03/2018
#
#      travel_time travel_from travel_to car_type  max_capacity
# 411        10:00       Kisii   Nairobi  shuttle            11
# 1370       10:00       Kisii   Nairobi  shuttle            11
# 1371       10:00       Kisii   Nairobi  shuttle            11
# 1372       10:00       Kisii   Nairobi  shuttle            11
# 2061       10:00       Kisii   Nairobi  shuttle            11

# %%
df.index
# Out:
# RangeIndex(start=0, stop=51645, step=1)

# %%
plt.figure(figsize=(15,8))
sector_name = df['travel_from'].value_counts()

sns.barplot(sector_name.values, sector_name.index)
for i, v in enumerate(sector_name.values):
    plt.text(0.8,i,v,color='k', fontsize=19)
    plt.xticks(rotation='vertical')
    plt.xlabel('Count')
    plt.ylabel('Travel_from')
    plt.title("Top Travel_from")
    plt.grid(True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df['travel_from'].value_counts()
# Out:
# Kisii        22607
# Migori        7027
# Homa Bay      6304
# Sirare        4449
# Rongo         3928
# Kehancha      1909
# Awendo        1788
# Kijauri       1031
# Keroka         988
# Nyachenge      512
# Rodi           405
# Mbita          378
# Ndhiwa         236
# Sori            55
# Keumbu          22
# Oyugis           5
# Kendu Bay        1
# Name: travel_from, dtype: int64

# %%
df['travel_time'].value_counts().head(50)
# Out:
# 7:09     3926
# 7:04     3837
# 7:12     3540
# 19:07    3227
# 7:08     2989
# 7:15     2146
# 7:13     1724
# 7:05     1675
# 7:06     1661
# 7:00     1603
# 8:00     1373
# 7:14     1181
# 7:07      784
# 8:40      673
# 8:30      672
# 8:10      671
# 8:20      670
# 9:20      660
# 7:03      656
# 8:50      650
# 9:00      647
# 9:10      646
# 9:30      630
# 7:50      628
# 9:40      589
# 7:30      582
# 7:40      571
# 7:20      549
# 9:50      520
# 10:00     506
# 10:20     498
# 10:10     497
# 7:10      491
# 6:59      457
# 10:30     444
# 6:50      442
# 10:40     411
# 6:40      405
# 19:04     402
# 5:00      388
# 6:30      377
# 10:50     341
# 19:03     334
# 10:51     300
# 23:10     288
# 5:10      277
# 10:52     274
# 7:11      259
# 6:20      250
# 10:53     238
# Name: travel_time, dtype: int64

# %%
df['travel_time'].max()
# Out:
# '9:50'

# %%
df['travel_from'].nunique()
# Out:
# 17

# %%
df['travel_time'].nunique()
# Out:
# 78

# %%
df['ride_id'].nunique()
# Out:
# 6249

# %%
df['seat_number'].nunique()
# Out:
# 61

# %%
df.ndim
# Out:
# 2

# %%
df_melt = pd.melt(df)

# %%
df_melt.head()
# Out:
#   variable value
# 0  ride_id  1442
# 1  ride_id  5437
# 2  ride_id  5710
# 3  ride_id  5777
# 4  ride_id  5778

# %%
df_stack = df.stack()

# %%
df_stack.head()
# Out:
# 0  ride_id                  1442
#    seat_number               15A
#    payment_method          Mpesa
#    payment_receipt    UZUEHCBUSO
#    travel_date        10/17/2017
# dtype: object

# %%
print("Top travel_from ", len(df["ride_id"].unique()))
print(df["travel_from"].value_counts().head(10))
# Out:
# Top travel_from  6249
# Kisii        22607
# Migori        7027
# Homa Bay      6304
# Sirare        4449
# Rongo         3928
# Kehancha      1909
# Awendo        1788
# Kijauri       1031
# Keroka         988
# Nyachenge      512
# Name: travel_from, dtype: int64

# %%
df_merge = pd.merge(df, df, on='ride_id')

# %%
df.head()
# Out:
#    ride_id seat_number_x payment_method_x payment_receipt_x travel_date_x  \
# 0     1442           15A            Mpesa        UZUEHCBUSO    10/17/2017
# 1     5437           14A            Mpesa        TIHLBUSGTE    11/19/2017
# 2     5710            8B            Mpesa        EQX8Q5G19O    11/26/2017
# 3     5777           19A            Mpesa        SGP18CL0ME    11/27/2017
# 4     5777           19A            Mpesa        SGP18CL0ME    11/27/2017
#
#   travel_time_x travel_from_x travel_to_x car_type_x  max_capacity_x  \
# 0          7:15        Migori     Nairobi        Bus              49
# 1          7:12        Migori     Nairobi        Bus              49
# 2          7:05        Keroka     Nairobi        Bus              49
# 3          7:10      Homa Bay     Nairobi        Bus              49
# 4          7:10      Homa Bay     Nairobi        Bus              49
#
#   seat_number_y payment_method_y payment_receipt_y travel_date_y  \
# ...

# %%
df.groupby('ride_id').sum()
# Out:
#          max_capacity
# ride_id
# 1442               49
# 5437               49
# 5710               49
# 5777              245
# 5778             1519
# 5781             1274
# 5784               11
# 5789               11
# 5790               98
# 5791               11
# 5792               11
# 5793               11
# 5794               22
# 5795               11
# 5796               22
# 5797              147
# 5798               11
# 5800               22
# 5801              121
# 5802               33
# 5803              121
# 5804               11
# 5808               98
# 5809               11
# 5810               11
# 5811               11
# 5812               11
# 5816               11
# 5817               11
# 5822               49
# ...               ...
# 13794             588
# 13795              49
# 13796            1323
# 13797              98
# 13798              98
# 13799              49
# 13800              49
# 13801             588
# 13802             343
# ...

# %%
for (method, group) in df.groupby('ride_id'):
    print("{0:30} shape={1}".format(method, group.shape))
# Out:
#                           1442 shape=(1, 10)
#                           5437 shape=(1, 10)
#                           5710 shape=(1, 10)
#                           5777 shape=(5, 10)
#                           5778 shape=(31, 10)
#                           5781 shape=(26, 10)
#                           5784 shape=(1, 10)
#                           5789 shape=(1, 10)
#                           5790 shape=(2, 10)
#                           5791 shape=(1, 10)
#                           5792 shape=(1, 10)
#                           5793 shape=(1, 10)
#                           5794 shape=(2, 10)
#                           5795 shape=(1, 10)
#                           5796 shape=(2, 10)
#                           5797 shape=(3, 10)
#                           5798 shape=(1, 10)
#                           5800 shape=(2, 10)
#                           5801 shape=(11, 10)
#                           5802 shape=(3, 10)
#                           5803 shape=(11, 10)
# ...

# %%
df.groupby('travel_from')['travel_date'].value_counts(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-9b0437f600cb> in <module>()
# ----> 1 df.groupby('travel_from')['travel_date'].value_counts(ascending=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     265         else:
#     266             if key not in self.obj:
# --> 267                 raise KeyError("Column not found: {key}".format(key=key))
#     268             return self._gotitem(key, ndim=1)
#     269
#
# KeyError: 'Column not found: travel_date'

# %%
L = df['travel_date']
print(df); print(df.groupby(L).sum())
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO  10/17/2017
# 1         5437         14A          Mpesa      TIHLBUSGTE  11/19/2017
# 2         5710          8B          Mpesa      EQX8Q5G19O  11/26/2017
# 3         5777         19A          Mpesa      SGP18CL0ME  11/27/2017
# 4         5778         11A          Mpesa      BM97HFRGL9  11/27/2017
# 5         5777         18B          Mpesa      B6PBDU30IZ  11/27/2017
# 6         5777         14A          Mpesa      MZHGDGS6QZ  11/27/2017
# 7         5778          25          Mpesa      MYVTYFNXDZ  11/27/2017
# 8         5778         21B          Mpesa      TE1WYK1NYE  11/27/2017
# 9         5781         22A          Mpesa      VGG7Q3MVJX  11/27/2017
# 10        5781         18B          Mpesa      YJ7JFHOGKA  11/27/2017
# 11        5781         17B          Mpesa      4JQOSC881A  11/27/2017
# ...

# %%
def norm_by_data2(travel_from):
    df_merge['ride_id'] /= df_merge['travel_from'].sum()
    return ride_id

print(df_merge); print(df_merge.groupby('ride_id').sum())
# Out:
#         ride_id seat_number_x payment_method_x payment_receipt_x  \
# 0          1442           15A            Mpesa        UZUEHCBUSO
# 1          5437           14A            Mpesa        TIHLBUSGTE
# 2          5710            8B            Mpesa        EQX8Q5G19O
# 3          5777           19A            Mpesa        SGP18CL0ME
# 4          5777           19A            Mpesa        SGP18CL0ME
# 5          5777           19A            Mpesa        SGP18CL0ME
# 6          5777           19A            Mpesa        SGP18CL0ME
# 7          5777           19A            Mpesa        SGP18CL0ME
# 8          5777           18B            Mpesa        B6PBDU30IZ
# 9          5777           18B            Mpesa        B6PBDU30IZ
# 10         5777           18B            Mpesa        B6PBDU30IZ
# 11         5777           18B            Mpesa        B6PBDU30IZ
# 12         5777           18B            Mpesa        B6PBDU30IZ
# ...

# %%
# %matplotlib inline
import matplotlib as plt

sns.set()
df.pivot_table('ride_id', index='travel_date', columns='travel_from', aggfunc='sum').plot()
plt.ylabel=('total trips by date')

# %% [markdown]
# travel_from_sum = df['ride_id'].sum /= df['travel_from']
# print(travel_from_sum)

# %%
#transform dates into columns for year month day
# feature engineer date so we can use the specifics in our ML model

df['travel_date']=pd.to_datetime(df['travel_date'])
df['Year']=df['travel_date'].apply(lambda x:x.year)
df['Month']=df['travel_date'].apply(lambda x:x.month)
df['Day']=df['travel_date'].apply(lambda x:x.day)

# %%
df.dropna().describe()
# Out:
#             ride_id  max_capacity         Month           Day          Year
# count  51645.000000  51645.000000  51645.000000  51645.000000  51645.000000
# mean   10188.645793     34.534321      4.961778     14.457779   2017.734727
# std     2211.295708     18.451193      4.279107      8.140845      0.441482
# min     1442.000000     11.000000      1.000000      1.000000   2017.000000
# 25%     8287.000000     11.000000      2.000000      8.000000   2017.000000
# 50%    10353.000000     49.000000      3.000000     14.000000   2018.000000
# 75%    12029.000000     49.000000     11.000000     20.000000   2018.000000
# max    20117.000000     49.000000     12.000000     31.000000   2018.000000

# %%
regions = ['Kisii', 'Migori', 'Homa Bay']

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, annot=True, cmap='coolwarm', square=True)
corr
# Out:
#                ride_id  max_capacity     Month       Day      Year
# ride_id       1.000000      0.295902  0.034532  0.032299  0.059424
# max_capacity  0.295902      1.000000 -0.149319  0.054198  0.198429
# Month         0.034532     -0.149319  1.000000 -0.010467 -0.978756
# Day           0.032299      0.054198 -0.010467  1.000000 -0.046853
# Year          0.059424      0.198429 -0.978756 -0.046853  1.000000

# %%
df[df['travel_from'] == 'Kisii'].groupby('ride_id').sum()
# Out:
#          max_capacity  Month  Day   Year
# ride_id
# 5784               11      4   20   2018
# 5789               11      4   20   2018
# 5790               98      8   40   4036
# 5791               11      4   20   2018
# 5792               11      4   20   2018
# 5793               11      4   20   2018
# 5794               22      8   40   4036
# 5795               11      4   20   2018
# 5796               22      8   40   4036
# 5798               11      4   20   2018
# 5800               22      8   38   4036
# 5801              121     44  209  22198
# 5803              121     44  209  22198
# 5808               98      8   38   4036
# 5809               11      4   19   2018
# 5810               11      4   19   2018
# 5811               11      4   19   2018
# 5812               11      4   19   2018
# 5816               11      4   18   2018
# 5817               11      4   18   2018
# 5822               49      4   18   2018
# 5823               22      8   36   4036
# ...

# %%
df_ride = df.groupby(['ride_id','travel_from', 'travel_date', 'seat_number']).count()

# %%
df_ride.head(300)
# Out:
#                                              payment_method  payment_receipt  \
# ride_id travel_from travel_date seat_number
# 1442    Migori      10/17/2017  15A                       1                1
# 5437    Migori      11/19/2017  14A                       1                1
# 5710    Keroka      11/26/2017  8B                        1                1
# 5777    Homa Bay    11/27/2017  14A                       1                1
#                                 15B                       1                1
#                                 16B                       1                1
#                                 18B                       1                1
#                                 19A                       1                1
# 5778    Migori      11/27/2017  10A                       1                1
#                                 11A                       1                1
#                                 13B                       1                1
# ...

# %%
df.index = pd.to_datetime(1000* df.Year +
                                  100 * df.Month +
                                  df.Day, format='%Y%M%d')
df['dayofweek'] = df.index.dayofweek

# %%
df.groupby("ride_id").count()
# Out:
#          seat_number  payment_method  payment_receipt  travel_date  \
# ride_id
# 1442               1               1                1            1
# 5437               1               1                1            1
# 5710               1               1                1            1
# 5777               5               5                5            5
# 5778              31              31               31           31
# 5781              26              26               26           26
# 5784               1               1                1            1
# 5789               1               1                1            1
# 5790               2               2                2            2
# 5791               1               1                1            1
# 5792               1               1                1            1
# 5793               1               1                1            1
# 5794               2               2                2            2
# ...

# %%
towns = pd.Series(['travel_from'])
towns
# Out:
# 0    travel_from
# dtype: object

# %%
df.plot()

# %%
from datetime import datetime

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\train_revised_11.09.2018\train_revised.csv', index_col='travel_date', parse_dates=True)
df.head()
# Out:
#              ride_id seat_number payment_method payment_receipt travel_time  \
# travel_date
# 2017-10-17      1442         15A          Mpesa      UZUEHCBUSO        7:15
# 2017-11-19      5437         14A          Mpesa      TIHLBUSGTE        7:12
# 2017-11-26      5710          8B          Mpesa      EQX8Q5G19O        7:05
# 2017-11-27      5777         19A          Mpesa      SGP18CL0ME        7:10
# 2017-11-27      5778         11A          Mpesa      BM97HFRGL9        7:12
#
#             travel_from travel_to car_type  max_capacity
# travel_date
# 2017-10-17       Migori   Nairobi      Bus            49
# 2017-11-19       Migori   Nairobi      Bus            49
# 2017-11-26       Keroka   Nairobi      Bus            49
# 2017-11-27     Homa Bay   Nairobi      Bus            49
# 2017-11-27       Migori   Nairobi      Bus            49

# %% [raw]
# df_ride.plot()

# %%
df.dtypes
# Out:
# ride_id             int64
# seat_number        object
# payment_method     object
# payment_receipt    object
# travel_date        object
# travel_time        object
# travel_from        object
# travel_to          object
# car_type           object
# max_capacity        int64
# dtype: object

# %%
df['ride_id'].astype(int).astype(object)
# Out:
# 0         1442
# 1         5437
# 2         5710
# 3         5777
# 4         5778
# 5         5777
# 6         5777
# 7         5778
# 8         5778
# 9         5781
# 10        5781
# 11        5781
# 12        5784
# 13        5789
# 14        5778
# 15        5790
# 16        5791
# 17        5792
# 18        5793
# 19        5790
# 20        5794
# 21        5781
# 22        5778
# 23        5795
# 24        5796
# 25        5796
# 26        5794
# 27        5797
# 28        5798
# 29        5797
#          ...
# 51615    13812
# 51616    13807
# 51617    13807
# 51618    13793
# 51619    13793
# 51620    13793
# 51621    13807
# 51622    13796
# 51623    13796
# 51624    13813
# 51625    13813
# 51626    13796
# 51627    13813
# 51628    13813
# 51629    13801
# 51630    13813
# 51631    13809
# 51632    13809
# 51633    13813
# 51634    13812
# 51635    13812
# 51636    13813
# 51637    13812
# 51638    13812
# 51639    13825
# 51640    13826
# 51641    13809
# ...

# %%
df_calc = df['ride_id']==df['travel_from']

# %%
df_ride.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023182454080>,
# ...
#       dtype=object)

# %%
dataset = DataSet()
data = dataset.get_original_dataframe()
data_p = dataset.get_dataframe()
print(data.head())
print('N: ', len(data))
print('Number of tickets bought by mpesa:', sum(data['payment_method'] == "Mpesa"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0d0b8c4bc0ae> in <module>()
# ----> 1 dataset = DataSet()
#       2 data = dataset.get_original_dataframe()
#       3 data_p = dataset.get_dataframe()
#       4 print(data.head())
#       5 print('N: ', len(data))
#
# NameError: name 'DataSet' is not defined

# %%
# Computing number of seats tacken / rides
to_print = []
for town_of_provenance in set(df['travel_from']):
    num_tickets = sum(df["travel_from"] == town_of_provenance)
    num_trips = sum(data_p["travel_from_" + town_of_provenance] == 1)
    num_tickets_per_trip = num_tickets / num_trips
    to_print.append((town_of_provenance, num_tickets, num_trips, num_tickets_per_trip))

print(tabulate(to_print, headers=["travel_from", "num_tickets", "num_trips", "num_tickets_per_trip"]))
